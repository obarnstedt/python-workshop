# %% [markdown]
# <a href="https://colab.research.google.com/github/obarnstedt/LINdoscope2023/blob/main/notebooks/intro_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with packages and modules

# %% [markdown]
# So far, we have been using Python's internal functions. These are very limited, but, thankfully, there is a plethora of packages that can do most tasks you desire. Because many of these packages are quite complex in the functionality they provide and their interdependencies with other packages, it is important to work with virtual environments, e.g., through conda, for specific projects/workflows/complex packages.

# %%
abs(-5)
# Out:
# 5

# %%
#sqrt(4)

# %%
# importing packages
import numpy  # comprehensive package for numeric array calculations

# %%
numpy.sqrt(4)
# Out:
# 2.0

# %%
import numpy as np  # if you're lazy...

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
#randint(10)  # this function doesn't exist in vanilla Python

# %%
np.random.randint(10)  # random number generator (integers from 0 to 10)
# Out:
# 8

# %%
from numpy import random  # you can import specific "MODULES" from packages like so
random.randint(10)
# Out:
# 5

# %%
from numpy import random as rnd  # you can also give them names you like
rnd.randint(10)
# Out:
# 0

# %% [markdown]
# # Pandas basics
# parts modified from https://pandas.pydata.org/docs/user_guide/10min.html

# %%
import pandas as pd  # numpy-based dataframe calculations

# %% [markdown]
# Pandas provides two types of classes for handling data:
#
# Series: a one-dimensional labeled array holding data of any type
# such as integers, strings, Python objects etc.
#
# DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
array = np.random.rand(20, 4)
array
# Out:
# array([[9.64323036e-01, 1.25428928e-01, 6.16250747e-01, 3.77083957e-01],
#        [1.27480965e-01, 9.78857229e-01, 5.93942779e-01, 6.93902303e-01],
#        [7.38665192e-01, 7.03421384e-01, 7.46529956e-01, 3.16899538e-01],
#        [5.74754556e-01, 3.85434326e-01, 6.71552798e-02, 2.10412946e-01],
#        [5.21405779e-02, 5.49016881e-01, 6.98939945e-01, 1.77787312e-01],
#        [7.41836792e-01, 8.53553072e-01, 2.39986278e-01, 9.10084300e-01],
#        [1.53663447e-01, 6.46837965e-02, 3.61550032e-01, 3.51468103e-01],
#        [4.41064090e-01, 3.01225295e-01, 6.04675512e-01, 2.58179752e-01],
#        [5.92372355e-02, 9.86442023e-01, 9.63252434e-01, 1.04459499e-01],
#        [1.04696003e-01, 7.35780422e-01, 8.85665732e-01, 9.66903987e-01],
#        [3.76022332e-01, 1.33096791e-01, 3.06794588e-01, 6.03240740e-01],
#        [5.93003009e-01, 7.11613208e-02, 5.33448366e-01, 5.41161358e-01],
#        [9.38778609e-01, 6.62504932e-01, 4.17972945e-01, 8.07903346e-01],
#        [7.82208890e-01, 6.53467544e-01, 2.35116568e-01, 7.05153743e-01],
#        [7.05964644e-01, 7.61703009e-01, 8.90581554e-04, 9.64474131e-01],
#        [2.47825725e-02, 9.22069680e-01, 8.74908581e-01, 1.62928827e-01],
#        [6.99511361e-01, 9.45352379e-01, 9.88814101e-01, 1.43100090e-02],
#        [2.43038895e-01, 8.45264543e-01, 6.36678753e-01, 6.18126983e-01],
#        [4.92308451e-01, 9.70716826e-01, 8.37671670e-01, 3.33556218e-01],
#        [2.98806166e-01, 1.20042595e-01, 1.25620809e-01, 6.82091689e-01]])

# %%
df = pd.DataFrame(data=array, index=range(20), columns=['col1', 'col2', 'col3', 'col4'])
df
# Out:
#         col1      col2      col3      col4
# 0   0.964323  0.125429  0.616251  0.377084
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 3   0.574755  0.385434  0.067155  0.210413
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241
# 11  0.593003  0.071161  0.533448  0.541161
# 12  0.938779  0.662505  0.417973  0.807903
# 13  0.782209  0.653468  0.235117  0.705154
# 14  0.705965  0.761703  0.000891  0.964474
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %% [markdown]
# ## Viewing

# %%
df.dtypes  # data types
# Out:
# col1    float64
# col2    float64
# col3    float64
# col4    float64
# dtype: object

# %%
df.head()
# Out:
#        col1      col2      col3      col4
# 0  0.964323  0.125429  0.616251  0.377084
# 1  0.127481  0.978857  0.593943  0.693902
# 2  0.738665  0.703421  0.746530  0.316900
# 3  0.574755  0.385434  0.067155  0.210413
# 4  0.052141  0.549017  0.698940  0.177787

# %%
df.tail(3)
# Out:
#         col1      col2      col3      col4
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4'], dtype='object')

# %%
df.describe()
# Out:
#             col1       col2       col3       col4
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.455614   0.588461   0.536793   0.490006
# std     0.309614   0.341424   0.304428   0.297745
# min     0.024783   0.064684   0.000891   0.014310
# 25%     0.147118   0.259193   0.290093   0.246238
# 50%     0.466686   0.682963   0.599309   0.459123
# 75%     0.714140   0.870682   0.769315   0.696715
# max     0.964323   0.986442   0.988814   0.966904

# %%
df.T  # transpose
# Out:
#             0         1         2         3         4         5         6   \
# col1  0.964323  0.127481  0.738665  0.574755  0.052141  0.741837  0.153663
# col2  0.125429  0.978857  0.703421  0.385434  0.549017  0.853553  0.064684
# col3  0.616251  0.593943  0.746530  0.067155  0.698940  0.239986  0.361550
# col4  0.377084  0.693902  0.316900  0.210413  0.177787  0.910084  0.351468
#
#             7         8         9         10        11        12        13  \
# col1  0.441064  0.059237  0.104696  0.376022  0.593003  0.938779  0.782209
# col2  0.301225  0.986442  0.735780  0.133097  0.071161  0.662505  0.653468
# col3  0.604676  0.963252  0.885666  0.306795  0.533448  0.417973  0.235117
# col4  0.258180  0.104459  0.966904  0.603241  0.541161  0.807903  0.705154
#
#             14        15        16        17        18        19
# col1  0.705965  0.024783  0.699511  0.243039  0.492308  0.298806
# col2  0.761703  0.922070  0.945352  0.845265  0.970717  0.120043
# col3  0.000891  0.874909  0.988814  0.636679  0.837672  0.125621
# col4  0.964474  0.162929  0.014310  0.618127  0.333556  0.682092

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#         col4      col3      col2      col1
# 0   0.377084  0.616251  0.125429  0.964323
# 1   0.693902  0.593943  0.978857  0.127481
# 2   0.316900  0.746530  0.703421  0.738665
# 3   0.210413  0.067155  0.385434  0.574755
# 4   0.177787  0.698940  0.549017  0.052141
# 5   0.910084  0.239986  0.853553  0.741837
# 6   0.351468  0.361550  0.064684  0.153663
# 7   0.258180  0.604676  0.301225  0.441064
# 8   0.104459  0.963252  0.986442  0.059237
# 9   0.966904  0.885666  0.735780  0.104696
# 10  0.603241  0.306795  0.133097  0.376022
# 11  0.541161  0.533448  0.071161  0.593003
# 12  0.807903  0.417973  0.662505  0.938779
# 13  0.705154  0.235117  0.653468  0.782209
# 14  0.964474  0.000891  0.761703  0.705965
# 15  0.162929  0.874909  0.922070  0.024783
# 16  0.014310  0.988814  0.945352  0.699511
# 17  0.618127  0.636679  0.845265  0.243039
# 18  0.333556  0.837672  0.970717  0.492308
# 19  0.682092  0.125621  0.120043  0.298806

# %%
df.sort_values(by="col2")
# Out:
#         col1      col2      col3      col4
# 6   0.153663  0.064684  0.361550  0.351468
# 11  0.593003  0.071161  0.533448  0.541161
# 19  0.298806  0.120043  0.125621  0.682092
# 0   0.964323  0.125429  0.616251  0.377084
# 10  0.376022  0.133097  0.306795  0.603241
# 7   0.441064  0.301225  0.604676  0.258180
# 3   0.574755  0.385434  0.067155  0.210413
# 4   0.052141  0.549017  0.698940  0.177787
# 13  0.782209  0.653468  0.235117  0.705154
# 12  0.938779  0.662505  0.417973  0.807903
# 2   0.738665  0.703421  0.746530  0.316900
# 9   0.104696  0.735780  0.885666  0.966904
# 14  0.705965  0.761703  0.000891  0.964474
# 17  0.243039  0.845265  0.636679  0.618127
# 5   0.741837  0.853553  0.239986  0.910084
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 18  0.492308  0.970717  0.837672  0.333556
# 1   0.127481  0.978857  0.593943  0.693902
# 8   0.059237  0.986442  0.963252  0.104459

# %% [markdown]
# ## Indexing

# %%
df["col3"]
# Out:
# 0     0.616251
# 1     0.593943
# 2     0.746530
# 3     0.067155
# 4     0.698940
# 5     0.239986
# 6     0.361550
# 7     0.604676
# 8     0.963252
# 9     0.885666
# 10    0.306795
# 11    0.533448
# 12    0.417973
# 13    0.235117
# 14    0.000891
# 15    0.874909
# 16    0.988814
# 17    0.636679
# 18    0.837672
# 19    0.125621
# Name: col3, dtype: float64

# %%
df[17:20]
# Out:
#         col1      col2      col3      col4
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.loc[17:20]  # more versatile
# Out:
#         col1      col2      col3      col4
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.loc[15:16, ["col2", "col4"]]  # always FIRST ROW, then SECOND COLUMN
# Out:
#         col2      col4
# 15  0.922070  0.162929
# 16  0.945352  0.014310

# %%
df.loc[(df.col1 > 0.5) & (df.col2 < 0.5)]  # select all rows where 'col1' is greater 0.5, 'col2' is smaller 0.5
# Out:
#         col1      col2      col3      col4
# 0   0.964323  0.125429  0.616251  0.377084
# 3   0.574755  0.385434  0.067155  0.210413
# 11  0.593003  0.071161  0.533448  0.541161

# %%
df.iloc[3:5, 0:2]  # selecting by position: ILOC
# Out:
#        col1      col2
# 3  0.574755  0.385434
# 4  0.052141  0.549017

# %% [markdown]
# ## Missing values

# %%
df.loc[(df.col1>0.5)&(df.col2<0.5)] = np.nan  # set these rows to NAN
df
# Out:
#         col1      col2      col3      col4
# 0        NaN       NaN       NaN       NaN
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 3        NaN       NaN       NaN       NaN
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241
# 11       NaN       NaN       NaN       NaN
# 12  0.938779  0.662505  0.417973  0.807903
# 13  0.782209  0.653468  0.235117  0.705154
# 14  0.705965  0.761703  0.000891  0.964474
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.dropna()  # drop all rows with missing values (not saved!)
# Out:
#         col1      col2      col3      col4
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241
# 12  0.938779  0.662505  0.417973  0.807903
# 13  0.782209  0.653468  0.235117  0.705154
# 14  0.705965  0.761703  0.000891  0.964474
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.fillna(value=0)
# Out:
#         col1      col2      col3      col4
# 0   0.000000  0.000000  0.000000  0.000000
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 3   0.000000  0.000000  0.000000  0.000000
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241
# 11  0.000000  0.000000  0.000000  0.000000
# 12  0.938779  0.662505  0.417973  0.807903
# 13  0.782209  0.653468  0.235117  0.705154
# 14  0.705965  0.761703  0.000891  0.964474
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %%
df.isna()
# Out:
#      col1   col2   col3   col4
# 0    True   True   True   True
# 1   False  False  False  False
# 2   False  False  False  False
# 3    True   True   True   True
# 4   False  False  False  False
# 5   False  False  False  False
# 6   False  False  False  False
# 7   False  False  False  False
# 8   False  False  False  False
# 9   False  False  False  False
# 10  False  False  False  False
# 11   True   True   True   True
# 12  False  False  False  False
# 13  False  False  False  False
# 14  False  False  False  False
# 15  False  False  False  False
# 16  False  False  False  False
# 17  False  False  False  False
# 18  False  False  False  False
# 19  False  False  False  False

# %%
df.interpolate(method='linear')  # interpolate missing values with 'linear' method
# Out:
#         col1      col2      col3      col4
# 0        NaN       NaN       NaN       NaN
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 3   0.395403  0.626219  0.722735  0.247343
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241
# 11  0.657400  0.397801  0.362384  0.705572
# 12  0.938779  0.662505  0.417973  0.807903
# 13  0.782209  0.653468  0.235117  0.705154
# 14  0.705965  0.761703  0.000891  0.964474
# 15  0.024783  0.922070  0.874909  0.162929
# 16  0.699511  0.945352  0.988814  0.014310
# 17  0.243039  0.845265  0.636679  0.618127
# 18  0.492308  0.970717  0.837672  0.333556
# 19  0.298806  0.120043  0.125621  0.682092

# %% [markdown]
# ## Operations

# %%
df.mean()
# Out:
# col1    0.410600
# col2    0.658070
# col3    0.559942
# col4    0.510086
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0          NaN
# 1     0.598546
# 2     0.626379
# 3          NaN
# 4     0.369471
# 5     0.686365
# 6     0.232841
# 7     0.401286
# 8     0.528348
# 9     0.673262
# 10    0.354789
# 11         NaN
# 12    0.706790
# 13    0.593987
# 14    0.608258
# 15    0.496172
# 16    0.661997
# 17    0.585777
# 18    0.658563
# 19    0.306640
# dtype: float64

# %%
df.rolling(window=3).mean()[::3] # 3x downsampling; using pandas dataframe METHOD (note: this is not saved!)
# Out:
#         col1      col2      col3      col4
# 0        NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN
# 6   0.315880  0.489085  0.433492  0.479780
# 9   0.201666  0.674483  0.817865  0.443181
# 12       NaN       NaN       NaN       NaN
# 15  0.504319  0.779080  0.370305  0.610852
# 18  0.478286  0.920445  0.821055  0.321998

# %%
df.agg(lambda x: np.mean(x) * 5.6)  # apply for each column
# Out:
# col1    2.299362
# col2    3.685195
# col3    3.135674
# col4    2.856484
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)  # apply for each cell
# Out:
#          col1       col2        col3       col4
# 0         NaN        NaN         NaN        NaN
# 1   12.901074  99.060352   60.107009  70.222913
# 2   74.752917  71.186244   75.548832  32.070233
# 3         NaN        NaN         NaN        NaN
# 4    5.276626  55.560508   70.732722  17.992076
# 5   75.073883  86.379571   24.286611  92.100531
# 6   15.550741   6.546000   36.588863  35.568572
# 7   44.635686  30.484000   61.193162  26.127791
# 8    5.994808  99.827933   97.481146  10.571301
# 9   10.595235  74.460979   89.629372  97.850684
# 10  38.053460  13.469395   31.047612  61.047963
# 11        NaN        NaN         NaN        NaN
# 12  95.004395  67.045499   42.298862  81.759819
# 13  79.159540  66.130915   23.793797  71.361559
# 14  71.443622  77.084345    0.090127  97.604782
# 15   2.507996  93.313452   88.540748  16.488397
# 16  70.790550  95.669661  100.067987   1.448173
# 17  24.595536  85.540772   64.431890  62.554451
# 18  49.821615  98.236543   84.772373  33.755889
# 19  30.239184  12.148311   12.712826  69.027679

# %%
df.fillna(0).multiply(10).astype(int)  # you can concatenate methods!
# Out:
#     col1  col2  col3  col4
# 0      0     0     0     0
# 1      1     9     5     6
# 2      7     7     7     3
# 3      0     0     0     0
# 4      0     5     6     1
# 5      7     8     2     9
# 6      1     0     3     3
# 7      4     3     6     2
# 8      0     9     9     1
# 9      1     7     8     9
# 10     3     1     3     6
# 11     0     0     0     0
# 12     9     6     4     8
# 13     7     6     2     7
# 14     7     7     0     9
# 15     0     9     8     1
# 16     6     9     9     0
# 17     2     8     6     6
# 18     4     9     8     3
# 19     2     1     1     6

# %% [markdown]
# ## Merging

# %%
pieces = [df[:3], df[3:7], df[7:11]]
pieces
# Out:
# [       col1      col2      col3      col4
#  0       NaN       NaN       NaN       NaN
#  1  0.127481  0.978857  0.593943  0.693902
#  2  0.738665  0.703421  0.746530  0.316900,
#         col1      col2      col3      col4
#  3       NaN       NaN       NaN       NaN
#  4  0.052141  0.549017  0.698940  0.177787
#  5  0.741837  0.853553  0.239986  0.910084
#  6  0.153663  0.064684  0.361550  0.351468,
#          col1      col2      col3      col4
#  7   0.441064  0.301225  0.604676  0.258180
#  8   0.059237  0.986442  0.963252  0.104459
#  9   0.104696  0.735780  0.885666  0.966904
#  10  0.376022  0.133097  0.306795  0.603241]

# %%
pd.concat(pieces)
# Out:
#         col1      col2      col3      col4
# 0        NaN       NaN       NaN       NaN
# 1   0.127481  0.978857  0.593943  0.693902
# 2   0.738665  0.703421  0.746530  0.316900
# 3        NaN       NaN       NaN       NaN
# 4   0.052141  0.549017  0.698940  0.177787
# 5   0.741837  0.853553  0.239986  0.910084
# 6   0.153663  0.064684  0.361550  0.351468
# 7   0.441064  0.301225  0.604676  0.258180
# 8   0.059237  0.986442  0.963252  0.104459
# 9   0.104696  0.735780  0.885666  0.966904
# 10  0.376022  0.133097  0.306795  0.603241

# %% [markdown]
# ## Pivot tables

# %%
df2 = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df2
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.360846  0.906995
# 1     one  B  foo  0.798604 -0.363912
# 2     two  C  foo -0.431161  0.746849
# 3   three  A  bar  1.581721  0.125280
# 4     one  B  bar -2.049706  1.547749
# 5     one  C  bar -0.623813 -0.531619
# 6     two  A  foo -2.386376  0.510941
# 7   three  B  foo -0.406205 -1.033913
# 8     one  C  foo -0.623031  0.430885
# 9     one  A  bar  0.735712 -0.793190
# 10    two  B  bar -0.231080 -1.897399
# 11  three  C  bar -0.743877 -0.481271

# %%
df_pivot = pd.pivot_table(df2, values="D", index=["A", "B"], columns=["C"])
df_pivot
# Out:
# C             bar       foo
# A     B
# one   A  0.735712 -0.360846
#       B -2.049706  0.798604
#       C -0.623813 -0.623031
# three A  1.581721       NaN
#       B       NaN -0.406205
#       C -0.743877       NaN
# two   A       NaN -2.386376
#       B -0.231080       NaN
#       C       NaN -0.431161

# %% [markdown]
# # Importing and exporting data

# %% [markdown]
# ## Export formats

# %%
df.to_csv("../files/foo.csv")

# %%
pd.read_csv("../files/foo.csv")
# Out:
#     Unnamed: 0      col1      col2      col3      col4
# 0            0       NaN       NaN       NaN       NaN
# 1            1  0.127481  0.978857  0.593943  0.693902
# 2            2  0.738665  0.703421  0.746530  0.316900
# 3            3       NaN       NaN       NaN       NaN
# 4            4  0.052141  0.549017  0.698940  0.177787
# 5            5  0.741837  0.853553  0.239986  0.910084
# 6            6  0.153663  0.064684  0.361550  0.351468
# 7            7  0.441064  0.301225  0.604676  0.258180
# 8            8  0.059237  0.986442  0.963252  0.104459
# 9            9  0.104696  0.735780  0.885666  0.966904
# 10          10  0.376022  0.133097  0.306795  0.603241
# 11          11       NaN       NaN       NaN       NaN
# 12          12  0.938779  0.662505  0.417973  0.807903
# 13          13  0.782209  0.653468  0.235117  0.705154
# 14          14  0.705965  0.761703  0.000891  0.964474
# 15          15  0.024783  0.922070  0.874909  0.162929
# 16          16  0.699511  0.945352  0.988814  0.014310
# 17          17  0.243039  0.845265  0.636679  0.618127
# 18          18  0.492308  0.970717  0.837672  0.333556
# 19          19  0.298806  0.120043  0.125621  0.682092

# %%
df.to_clipboard()

# %%
df.to_excel("../files/foo.xlsx")

# %%
df.to_hdf("../files/foo.h5", key='df')

# %%
df.to_feather("../files/foo.feather")

# %% [markdown]
# # Playaround dataset

# %% [markdown]
# There's a "playaround.feather" file in the "files" folder. Try the following:
# 1. Open it
# 2. What is the 'likelihood' value at index 17?
# 3. What are the median values for the three columns?
# 4. Are there NAN values?
# 5. Fill the NAN values with -1
# 6. Find all values with -1 and set them to NAN
# 7. Interpolate missing values with a cubic spline function
# 8. Save the result as "playaround_edit.h5"

# %% [markdown]
# # Experimental dataset

# %% [markdown]
# The file "files/20230428_VGC_0647_LaserOFFDLC_testdataset.csv" contains the DeepLabCut output file of a mouse traversing 5 minutes in an elevated plus maze (EPM). Your task is to find out how much time in percentage the mouse spent in the open arms and how much time it spent in the closed arms.

# %% [markdown]
# Tip: In this case, the closed arm was positioned vertically, the open arms horizontally. Vertical walls are within 480 < x < 555.

# %% [markdown]
# For pros: Calculate the number of open arm entries

# %% [markdown]
# ## Importing data

# %%
dlc = pd.read_csv("../files/20230428_VGC_0647_LaserOFFDLC_testdataset.csv")
dlc
# Out:
#           scorer DLC_resnet50_EPMApr27shuffle1_850000  \
# 0      bodyparts                                 nose
# 1         coords                                    x
# 2              0                    484.6491394042969
# 3              1                    484.1271667480469
# 4              2                   484.54620361328125
# ...          ...                                  ...
# 11997      11995                    505.4471130371094
# 11998      11996                    504.7735290527344
# 11999      11997                   504.75067138671875
# 12000      11998                   503.94317626953125
# 12001      11999                    503.6434631347656
#
#       DLC_resnet50_EPMApr27shuffle1_850000.1  \
# 0                                       nose
# 1                                          y
# 2                          201.5142364501953
# 3                         202.01803588867188
# 4                          201.7998809814453
# ...                                      ...
# 11997                     492.70587158203125
# 11998                      492.8782958984375
# 11999                      493.0707092285156
# 12000                      492.6711730957031
# 12001                     492.57916259765625
#
#       DLC_resnet50_EPMApr27shuffle1_850000.2  \
# 0                                       nose
# 1                                 likelihood
# 2                         0.9965528249740601
# 3                         0.9954521059989929
# 4                         0.9969022870063782
# ...                                      ...
# 11997                     0.9998606443405151
# 11998                     0.9997372031211853
# 11999                     0.9997734427452087
# 12000                     0.9997828602790833
# 12001                     0.9997817873954773
#
#       DLC_resnet50_EPMApr27shuffle1_850000.3  \
# 0                                   left paw
# 1                                          x
# 2                           497.260009765625
# 3                          495.7225341796875
# 4                         495.71978759765625
# ...                                      ...
# 11997                      496.9927978515625
# 11998                      496.9559631347656
# 11999                      496.9162292480469
# 12000                      496.9664611816406
# 12001                      497.0026550292969
#
#       DLC_resnet50_EPMApr27shuffle1_850000.4  \
# 0                                   left paw
# 1                                          y
# 2                          184.5144500732422
# 3                          183.4581756591797
# 4                          183.4489288330078
# ...                                      ...
# 11997                      447.9296569824219
# 11998                      447.8119812011719
# 11999                      447.7670593261719
# 12000                      447.7694396972656
# 12001                     447.79095458984375
#
#       DLC_resnet50_EPMApr27shuffle1_850000.5  \
# 0                                   left paw
# 1                                 likelihood
# 2                         0.9917073845863342
# 3                         0.9817245006561279
# 4                         0.9802581071853638
# ...                                      ...
# 11997                     0.9999939203262329
# 11998                     0.9999938011169434
# 11999                     0.9999938011169434
# 12000                     0.9999940395355225
# 12001                     0.9999945163726807
#
#       DLC_resnet50_EPMApr27shuffle1_850000.6  \
# 0                                  right paw
# 1                                          x
# 2                           532.584716796875
# 3                            532.56494140625
# 4                          532.5015869140625
# ...                                      ...
# 11997                      513.1210327148438
# 11998                        513.05322265625
# 11999                           512.94921875
# 12000                      512.8672485351562
# 12001                      512.8384399414062
#
#       DLC_resnet50_EPMApr27shuffle1_850000.7  \
# 0                                  right paw
# 1                                          y
# 2                         198.62220764160156
# 3                          198.4882354736328
# 4                         198.50601196289062
# ...                                      ...
# 11997                      463.7508239746094
# 11998                      463.7399597167969
# 11999                     463.75726318359375
# 12000                      463.7599182128906
# 12001                      463.7349853515625
#
#       DLC_resnet50_EPMApr27shuffle1_850000.8  \
# 0                                  right paw
# 1                                 likelihood
# 2                         0.9999322891235352
# 3                         0.9999420642852783
# 4                         0.9999428987503052
# ...                                      ...
# 11997                     0.9999961853027344
# 11998                     0.9999960660934448
# 11999                     0.9999960660934448
# 12000                     0.9999957084655762
# 12001                     0.9999959468841553
#
#       DLC_resnet50_EPMApr27shuffle1_850000.9  \
# 0                               left hindpaw
# 1                                          x
# 2                          499.3367614746094
# 3                          499.2420349121094
# 4                          499.0804443359375
# ...                                      ...
# 11997                     488.94268798828125
# 11998                        488.94091796875
# 11999                     488.99041748046875
# 12000                      488.9565124511719
# 12001                      488.9396057128906
#
#       DLC_resnet50_EPMApr27shuffle1_850000.10  \
# 0                                left hindpaw
# 1                                           y
# 2                          170.40240478515625
# 3                          170.74761962890625
# 4                          170.94410705566406
# ...                                       ...
# 11997                      389.22479248046875
# 11998                       389.2264099121094
# 11999                       389.1574401855469
# 12000                       389.1590270996094
# 12001                       389.1881103515625
#
#       DLC_resnet50_EPMApr27shuffle1_850000.11  \
# 0                                left hindpaw
# 1                                  likelihood
# 2                          0.9999860525131226
# 3                          0.9999852180480957
# 4                          0.9999837875366211
# ...                                       ...
# 11997                       0.999998927116394
# 11998                      0.9999990463256836
# 11999                      0.9999990463256836
# 12000                      0.9999990463256836
# 12001                       0.999998927116394
#
#       DLC_resnet50_EPMApr27shuffle1_850000.12  \
# 0                               right hindpaw
# 1                                           x
# 2                               540.806640625
# 3                           540.7224731445312
# 4                           540.7445068359375
# ...                                       ...
# 11997                        541.878173828125
# 11998                          541.8779296875
# 11999                       542.2305908203125
# 12000                       541.8826293945312
# 12001                        541.843994140625
#
#       DLC_resnet50_EPMApr27shuffle1_850000.13  \
# 0                               right hindpaw
# 1                                           y
# 2                          163.20863342285156
# 3                              163.1923828125
# 4                           163.1587371826172
# ...                                       ...
# 11997                       393.3909606933594
# 11998                       393.4159851074219
# 11999                       393.5039367675781
# 12000                       393.4291076660156
# 12001                       393.4217834472656
#
#       DLC_resnet50_EPMApr27shuffle1_850000.14  \
# 0                               right hindpaw
# 1                                  likelihood
# 2                          0.9999994039535522
# 3                          0.9999994039535522
# 4                          0.9999994039535522
# ...                                       ...
# 11997                      0.9999945163726807
# 11998                      0.9999945163726807
# 11999                      0.9999945163726807
# 12000                      0.9999945163726807
# 12001                      0.9999946355819702
#
#       DLC_resnet50_EPMApr27shuffle1_850000.15  \
# 0                                        tail
# 1                                           x
# 2                           522.0670166015625
# 3                           522.0958251953125
# 4                             522.20166015625
# ...                                       ...
# 11997                       516.3087158203125
# 11998                       516.4034423828125
# 11999                       516.4120483398438
# 12000                       516.3770141601562
# 12001                        516.359130859375
#
#       DLC_resnet50_EPMApr27shuffle1_850000.16  \
# 0                                        tail
# 1                                           y
# 2                           135.1444549560547
# 3                           135.4122314453125
# 4                           135.3200225830078
# ...                                       ...
# 11997                        373.951416015625
# 11998                        373.970458984375
# 11999                       373.9803466796875
# 12000                      373.92620849609375
# 12001                      373.93170166015625
#
#       DLC_resnet50_EPMApr27shuffle1_850000.17
# 0                                        tail
# 1                                  likelihood
# 2                          0.9999971389770508
# 3                          0.9999970197677612
# 4                          0.9999972581863403
# ...                                       ...
# 11997                                     1.0
# 11998                                     1.0
# 11999                                     1.0
# 12000                                     1.0
# 12001                                     1.0
#
# [12002 rows x 19 columns]

# %% [markdown]
# ## Clean up dataframe

# %%
bodyparts = list(dlc.iloc[0, 1:].unique()) + ['centroid']
dlc.columns = [dlc.iloc[0], dlc.iloc[1]]
dlc = dlc.drop('bodyparts', axis=1).drop([0, 1], axis=0).reset_index(drop=True)
dlc = dlc.astype(float)
dlc
# Out:
# /var/folders/2s/lgxvrsmn351gfx01lgs9wft80000gn/T/ipykernel_11484/3557507285.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   dlc = dlc.drop('bodyparts', axis=1).drop([0, 1], axis=0).reset_index(drop=True)
# 0            nose                           left paw                         \
# 1               x           y likelihood           x           y likelihood
# 0      484.649139  201.514236   0.996553  497.260010  184.514450   0.991707
# 1      484.127167  202.018036   0.995452  495.722534  183.458176   0.981725
# 2      484.546204  201.799881   0.996902  495.719788  183.448929   0.980258
# 3      483.503876  202.272873   0.997923  497.498322  183.699356   0.993420
# 4      484.679871  203.999573   0.999774  494.976318  184.692993   0.999932
# ...           ...         ...        ...         ...         ...        ...
# 11995  505.447113  492.705872   0.999861  496.992798  447.929657   0.999994
# 11996  504.773529  492.878296   0.999737  496.955963  447.811981   0.999994
# 11997  504.750671  493.070709   0.999773  496.916229  447.767059   0.999994
# 11998  503.943176  492.671173   0.999783  496.966461  447.769440   0.999994
# 11999  503.643463  492.579163   0.999782  497.002655  447.790955   0.999995
#
# 0       right paw                        left hindpaw                         \
# 1               x           y likelihood            x           y likelihood
# 0      532.584717  198.622208   0.999932   499.336761  170.402405   0.999986
# 1      532.564941  198.488235   0.999942   499.242035  170.747620   0.999985
# 2      532.501587  198.506012   0.999943   499.080444  170.944107   0.999984
# 3      532.487976  198.398743   0.999966   498.371246  171.108597   0.999988
# 4      532.068176  198.287735   0.999982   499.239136  161.985825   0.999999
# ...           ...         ...        ...          ...         ...        ...
# 11995  513.121033  463.750824   0.999996   488.942688  389.224792   0.999999
# 11996  513.053223  463.739960   0.999996   488.940918  389.226410   0.999999
# 11997  512.949219  463.757263   0.999996   488.990417  389.157440   0.999999
# 11998  512.867249  463.759918   0.999996   488.956512  389.159027   0.999999
# 11999  512.838440  463.734985   0.999996   488.939606  389.188110   0.999999
#
# 0     right hindpaw                               tail
# 1                 x           y likelihood           x           y likelihood
# 0        540.806641  163.208633   0.999999  522.067017  135.144455   0.999997
# 1        540.722473  163.192383   0.999999  522.095825  135.412231   0.999997
# 2        540.744507  163.158737   0.999999  522.201660  135.320023   0.999997
# 3        540.778931  163.290070   0.999999  522.532532  135.116318   0.999998
# 4        540.774597  163.335007   1.000000  522.674927  135.367294   0.999998
# ...             ...         ...        ...         ...         ...        ...
# 11995    541.878174  393.390961   0.999995  516.308716  373.951416   1.000000
# 11996    541.877930  393.415985   0.999995  516.403442  373.970459   1.000000
# 11997    542.230591  393.503937   0.999995  516.412048  373.980347   1.000000
# 11998    541.882629  393.429108   0.999995  516.377014  373.926208   1.000000
# 11999    541.843994  393.421783   0.999995  516.359131  373.931702   1.000000
#
# [12000 rows x 18 columns]

# %% [markdown]
# ## Clean up low confidence data

# %%
# confidence thresholding
conf_thresh = 0.9
dlc_clean = dlc.copy().drop('likelihood', axis=1, level=1)
for marker_name in bodyparts[:-1]:
    dlc_clean.loc[(dlc.loc[:, (marker_name, 'likelihood')]<conf_thresh), (marker_name, ['x', 'y'])] = np.nan
dlc_clean = dlc_clean.interpolate(method='linear')

# %% [markdown]
# ## Calculate centroid

# %%
#calculate centroid
for x in ['x', 'y']:
    dlc_clean['centroid', x] = dlc_clean.loc[:,(dlc_clean.columns.get_level_values(0).unique(), x)].mean(axis=1)

# %% [markdown]
# ## Median-filter traces

# %%
# smoothed traces
dlc_smoothed = dlc_clean.rolling(200, center=True).median()
dlc_smoothed1s = dlc_clean.rolling(40, center=True).median()

# %% [markdown]
# ## Calculate relative time in open arm

# %%
xwalls = [480, 555]

# %%
# Time in open arm
dlc_clean['InOpen'] = False
dlc_clean.loc[((dlc_smoothed.centroid.x<xwalls[0])|(dlc_smoothed.centroid.x>xwalls[1])), 'InOpen'] = True

# %% [markdown]
# ## (Calculate number of open arm entries)

# %%
dlc_clean['EnterOpen'] = dlc_clean.InOpen.astype(int).diff()==1
first_open_entry = dlc_clean.loc[(dlc_clean.EnterOpen)].groupby(['Group', 'Mouse', 'Opto']).min()['Time_s']
entrytimes = pd.Series(dlc_clean.loc[(dlc_clean.EnterOpen), 'Time_s'].diff())
dlc_clean.loc[entrytimes.loc[(entrytimes>0)&(entrytimes<5)].index, 'EnterOpen'] = False # set minimum of 5 seconds between entries
